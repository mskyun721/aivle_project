# %%
import pandas as pd

result = pd.read_csv('data/result.csv')
result.sort_values(by=['r2score', 'rmse'], ascending=False)
# Out:
#                          data                      model  param         rmse  \
# 7   data/train/train_x_01.csv          CatBoostRegressor    NaN   770.034916
# 15         train_x_summary_01          CatBoostRegressor    NaN   799.126103
# 14         train_x_summary_01              LGBMRegressor    NaN   828.061606
# 6   data/train/train_x_01.csv              LGBMRegressor    NaN   830.223966
# 11         train_x_summary_01      RandomForestRegressor    NaN   841.552704
# 12         train_x_summary_01      RandomForestRegressor    NaN   871.283083
# 13         train_x_summary_01               XGBRegressor    NaN   881.048068
# 3   data/train/train_x_01.csv      RandomForestRegressor    NaN   889.217419
# 4   data/train/train_x_01.csv  GradientBoostingRegressor    NaN   904.656953
# 5   data/train/train_x_01.csv               XGBRegressor    NaN   930.037029
# 8          train_x_summary_01           LinearRegression    NaN  1356.054920
# ...
